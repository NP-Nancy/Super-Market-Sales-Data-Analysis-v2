# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\dell\Downloads\SuperMarket Analysis.csv")
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428   Alex     Yangon        Member  Female
# 1    226-31-3081   Giza  Naypyitaw        Normal  Female
# 2    631-41-3108   Alex     Yangon        Normal  Female
# 3    123-19-1176   Alex     Yangon        Member  Female
# 4    373-73-7910   Alex     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758   Giza  Naypyitaw        Normal    Male
# 996  303-96-2227  Cairo   Mandalay        Normal  Female
# 997  727-02-1313   Alex     Yangon        Member    Male
# 998  347-56-2442   Alex     Yangon        Normal    Male
# 999  849-09-3807   Alex     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Sales  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428   Alex     Yangon        Member  Female
# 1  226-31-3081   Giza  Naypyitaw        Normal  Female
# 2  631-41-3108   Alex     Yangon        Normal  Female
# 3  123-19-1176   Alex     Yangon        Member  Female
# 4  373-73-7910   Alex     Yangon        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Sales       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#           Time      Payment    cogs  gross margin percentage  gross income  \
# 0   1:08:00 PM      Ewallet  522.83                 4.761905       26.1415
# ...

# %%
data.shape
# Out:
# (1000, 17)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Sales                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
data.isnull().sum()      # This will check the missing values
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Sales                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
data[data.duplicated()]  # This will show the duplicate rows in the DataFrame
# Out:
# Empty DataFrame
# Columns: [Invoice ID, Branch, City, Customer type, Gender, Product line, Unit price, Quantity, Tax 5%, Sales, Date, Time, Payment, cogs, gross margin percentage, gross income, Rating]
# Index: []

# %%
data.duplicated().sum()  # This will give you the count of duplicate rows
# Out:
# np.int64(0)

# %%
data.drop_duplicates(inplace=True)  # This will delete the duplicates

# %%
if 'Total' in data.columns:
    branch_sales = data.groupby('Branch')['Total'].sum().sort_values(ascending=False)
else:
    print("The 'Total' column is not present in the data.")
# Out:
# The 'Total' column is not present in the data.

# %%
data['Total'] = data['Quantity'] * data['Unit price']

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428   Alex     Yangon        Member  Female
# 1  226-31-3081   Giza  Naypyitaw        Normal  Female
# 2  631-41-3108   Alex     Yangon        Normal  Female
# 3  123-19-1176   Alex     Yangon        Member  Female
# 4  373-73-7910   Alex     Yangon        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Sales       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#           Time      Payment    cogs  gross margin percentage  gross income  \
# 0   1:08:00 PM      Ewallet  522.83                 4.761905       26.1415
# ...

# %%
branch_sales = data.groupby('Branch')['Total'].sum().sort_values(ascending=False) #Top branch by sales

# %%
import seaborn as sns                    # Sales distribution by payment method
import matplotlib.pyplot as plt

sns.countplot(data, x='Payment')
plt.title("Payment Method Distribution")
plt.show()

# %%
# Convert Date column to datetime
data['Date'] = pd.to_datetime(data['Date'])

# Group by month and calculate total sales
monthly_sales = data.groupby(data['Date'].dt.month)['Total'].sum()

monthly_sales.plot(kind='bar', title="Monthly Sales Trend", ylabel="Total Sales")
# Out:
# <Axes: title={'center': 'Monthly Sales Trend'}, xlabel='Date', ylabel='Total Sales'>

# %%
data.groupby('Product line')['Total'].sum().sort_values(ascending=False)   #Top selling products
# Out:
# Product line
# Food and beverages        53471.28
# Sports and travel         52497.93
# Electronic accessories    51750.03
# Fashion accessories       51719.90
# Home and lifestyle        51297.06
# Health and beauty         46851.18
# Name: Total, dtype: float64

# %%
#Creating Visualization
#1.Payment method distribution
# Bar plot for payment methods
payment_counts = data['Payment'].value_counts()
payment_counts.plot(kind='bar', color=['skyblue', 'orange', 'green'], title='Payment Method Distribution')
plt.xlabel("Payment Method")
plt.ylabel("Count")
plt.show()

# %%
#2.Sales by product line
product_sales = data.groupby('Product line')['Total'].sum()
product_sales.plot(kind='bar', color='brown', title='Total Sales by Product Line')
plt.xlabel("Product Line")
plt.ylabel("Total Sales")
plt.show()

# %%
#3.Month;y sales trend
# Convert Date column to datetime
data['Date'] = pd.to_datetime(data['Date'])
data['Month'] = data['Date'].dt.month
# Grouping total sales by month
monthly_sales = data.groupby('Month')['Total'].sum()

# Line plot for monthly sales
monthly_sales.plot(kind='line', marker='o', color='purple', title='Monthly Sales Trend')
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.show()
